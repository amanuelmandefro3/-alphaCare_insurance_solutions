# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Loading dataset and convert from .txt to .csv

# %%
df = pd.read_csv('../data/MachineLearningRating_v3.txt', delimiter='|')
df.head()
# Out:
# /tmp/ipykernel_109092/2692656090.py:1: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/MachineLearningRating_v3.txt', delimiter='|')
#    UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0               145249     12827  2015-03-01 00:00:00             True
# 1               145249     12827  2015-05-01 00:00:00             True
# 2               145249     12827  2015-07-01 00:00:00             True
# 3               145255     12827  2015-05-01 00:00:00             True
# 4               145255     12827  2015-07-01 00:00:00             True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0              Close Corporation    Mr  English  First National Bank
# 1              Close Corporation    Mr  English  First National Bank
# 2              Close Corporation    Mr  English  First National Bank
# ...

# %%
# converting .txt file to .csv file
df.to_csv('../data/MachineLearningRating_v3.csv', index=False)

# %%
# loading the .csv file
df = pd.read_csv('../data/MachineLearningRating_v3.csv')
df.head()
# Out:
# /tmp/ipykernel_109092/3019675343.py:2: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/MachineLearningRating_v3.csv')
#    UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0               145249     12827  2015-03-01 00:00:00             True
# 1               145249     12827  2015-05-01 00:00:00             True
# 2               145249     12827  2015-07-01 00:00:00             True
# 3               145255     12827  2015-05-01 00:00:00             True
# 4               145255     12827  2015-07-01 00:00:00             True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0              Close Corporation    Mr  English  First National Bank
# 1              Close Corporation    Mr  English  First National Bank
# 2              Close Corporation    Mr  English  First National Bank
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000098 entries, 0 to 1000097
# Data columns (total 52 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   UnderwrittenCoverID       1000098 non-null  int64
#  1   PolicyID                  1000098 non-null  int64
#  2   TransactionMonth          1000098 non-null  object
#  3   IsVATRegistered           1000098 non-null  bool
#  4   Citizenship               1000098 non-null  object
#  5   LegalType                 1000098 non-null  object
#  6   Title                     1000098 non-null  object
#  7   Language                  1000098 non-null  object
#  8   Bank                      854137 non-null   object
#  9   AccountType               959866 non-null   object
#  10  MaritalStatus             991839 non-null   object
#  11  Gender                    990562 non-null   object
#  12  Country                   1000098 non-null  object
# ...

# %% [markdown]
# Data summarization

# %%
summary_stats = df.describe()
print(summary_stats)
# Out:
#        UnderwrittenCoverID      PolicyID    PostalCode        mmcode  \
# count         1.000098e+06  1.000098e+06  1.000098e+06  9.995460e+05
# mean          1.048175e+05  7.956682e+03  3.020601e+03  5.487770e+07
# std           6.329371e+04  5.290039e+03  2.649854e+03  1.360381e+07
# min           1.000000e+00  1.400000e+01  1.000000e+00  4.041200e+06
# 25%           5.514300e+04  4.500000e+03  8.270000e+02  6.005692e+07
# 50%           9.408300e+04  7.071000e+03  2.000000e+03  6.005842e+07
# 75%           1.391900e+05  1.107700e+04  4.180000e+03  6.005842e+07
# max           3.011750e+05  2.324600e+04  9.870000e+03  6.506535e+07
#
#        RegistrationYear      Cylinders  cubiccapacity      kilowatts  \
# count      1.000098e+06  999546.000000  999546.000000  999546.000000
# mean       2.010225e+03       4.046642    2466.743258      97.207919
# std        3.261391e+00       0.294020     442.800640      19.393256
# ...

# %% [markdown]
# Review Data types

# %%
print(df.dtypes)
# Out:
# UnderwrittenCoverID           int64
# PolicyID                      int64
# TransactionMonth             object
# IsVATRegistered                bool
# Citizenship                  object
# LegalType                    object
# Title                        object
# Language                     object
# Bank                         object
# AccountType                  object
# MaritalStatus                object
# Gender                       object
# Country                      object
# Province                     object
# PostalCode                    int64
# MainCrestaZone               object
# SubCrestaZone                object
# ItemType                     object
# mmcode                      float64
# VehicleType                  object
# RegistrationYear              int64
# make                         object
# Model                        object
# Cylinders                   float64
# cubiccapacity               float64
# kilowatts                   float64
# ...

# %% [markdown]
# Data quality Assessment

# %%
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# UnderwrittenCoverID               0
# PolicyID                          0
# TransactionMonth                  0
# IsVATRegistered                   0
# Citizenship                       0
# LegalType                         0
# Title                             0
# Language                          0
# Bank                         145961
# AccountType                   40232
# MaritalStatus                  8259
# Gender                         9536
# Country                           0
# Province                          0
# PostalCode                        0
# MainCrestaZone                    0
# SubCrestaZone                     0
# ItemType                          0
# mmcode                          552
# VehicleType                     552
# RegistrationYear                  0
# make                            552
# Model                           552
# Cylinders                       552
# cubiccapacity                   552
# kilowatts                       552
# ...

# %% [markdown]
# Univariate  Analysis

# %%
#Histograms for numerical columns
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns 
df[numerical_cols].hist(figsize=(15, 10))
plt.show()

# %%
# Bar charts for categorical columns
categorical_cols = df.select_dtypes(include=['object', 'bool']).columns
for col in categorical_cols:
    df[col].value_counts().plot(kind='bar')
    plt.title(col)
    plt.show()

# %% [markdown]
# Bivariate or Multivariate Analysis

# %%
#convert TransactionMonyh to datetime
df['TransactionMonth'] = pd.to_datetime(df['TransactionMonth'])
monthly_data = df.groupby(['PostalCode', 'TransactionMonth']).agg({
    'TotalPremium': 'sum',
    'TotalClaims': 'sum'
    }).reset_index()

#plot scatter plots
plt.figure(figsize=(15, 10))
sns.scatterplot(x='TotalPremium', y='TotalClaims', hue='PostalCode', data=monthly_data)
plt.title('Scatter plot of TotalPremium vs TotalClaims')
plt.show()

# %%
# correlation matrix

# calculate the correlation matrix
correlation_matrix =monthly_data[['TotalPremium', 'TotalClaims']].corr()

sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation matrix of TotalPremium and TotalClaims')
plt.show()

# %% [markdown]
# Data comparison

# %%
# compare change in insurance cover type, permium, auto make
sns.boxplot(x='CoverType', y='TotalPremium', data=df)
plt.show()

# %% [markdown]
# Outlier Detection

# %%
# Box plots fpr numerical data
for col in numerical_cols:
    df.boxplot(column=col)
    plt.title(col)
    plt.show()

# %% [markdown]
# Visualization

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x='TransactionMonth', y='TotalPremium', data=df)
plt.title('Monthly Total Premium')
plt.show()

plt.figure(figsize=(10, 6))
sns.barplot(x='VehicleType', y='TotalClaims', data=df)
plt.title('Total Claims by Vehicle Type')
plt.show()

plt.figure(figsize=(10, 6))
sns.scatterplot(x='PostalCode', y='TotalPremium', hue='CoverType', data=df)
plt.title('Total Premium by Postal Code and Cover Type')
plt.show()
# Out:
# /home/amr/project/10_Acedamy/alphaCare_insurance_solutions/.venv/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
